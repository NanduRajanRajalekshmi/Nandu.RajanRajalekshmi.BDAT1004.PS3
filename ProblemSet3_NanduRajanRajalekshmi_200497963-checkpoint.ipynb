# %% [markdown]
# BDAT-1004 Problem Set 3-Nandu Rajan Rajalekshmi-200497963

# %%
Question 1

# %% [markdown]
# Occupations
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called users

# %%
users=pd.read_csv('C:\\Users\\Nandu R R\\Documents\\BDAT\\Data Programming\\users.csv')

# %% [markdown]
# Step 4. Discover what is the mean age per occupation

# %%
x1=users.groupby('occupation').age.agg(['mean'])

# %%
x1
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
m=users[users['gender']=='M'].groupby('occupation').count()['gender']
t=users.groupby('occupation').count()['gender']
r=((m/t)*100).sort_values(ascending=False)

# %%
r
# Out:
# occupation
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# Name: gender, dtype: float64

# %% [markdown]
# Step 6. For each occupation, calculate the minimum and maximum ages

# %%
x2=users.groupby('occupation').age.agg([min,max])

# %%
x2
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# Step 7. For each combination of occupation and sex, calculate the mean age

# %%
x3=users.groupby(['occupation','gender']).age.agg(['mean'])

# %%
x3
# Out:
#                            mean
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %% [markdown]
# Step 8. For each occupation present the percentage of women and men

# %%
m=users[users['gender']=='M'].groupby('occupation').count()['gender']
t=users.groupby('occupation').count()['gender']
rm=((m/t)*100).sort_values(ascending=False)

# %%
f=users[users['gender']=='F'].groupby('occupation').count()['gender']
t=users.groupby('occupation').count()['gender']
rf=((f/t)*100).sort_values(ascending=False)

# %%
pd.concat([rm,rf],axis=1)
# Out:
#                    gender     gender
# occupation
# doctor         100.000000        NaN
# engineer        97.014925   2.985075
# technician      96.296296   3.703704
# retired         92.857143   7.142857
# programmer      90.909091   9.090909
# executive       90.625000   9.375000
# scientist       90.322581   9.677419
# entertainment   88.888889  11.111111
# lawyer          83.333333  16.666667
# salesman        75.000000  25.000000
# educator        72.631579  27.368421
# student         69.387755  30.612245
# other           65.714286  34.285714
# marketing       61.538462  38.461538
# writer          57.777778  42.222222
# none            55.555556  44.444444
# administrator   54.430380  45.569620
# artist          53.571429  46.428571
# librarian       43.137255  56.862745
# healthcare      31.250000  68.750000
# homemaker       14.285714  85.714286

# %% [markdown]
# Question 2
# Euro Teams
# Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called euro12

# %%
euro12=pd.read_csv('C:\\Users\\Nandu R R\\Documents\\BDAT\\Data Programming\\Euro_2012_stats_TEAM.csv')

# %% [markdown]
# Step 4. Select only the Goal column

# %%
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# Step 5. How many team participated in the Euro2012?

# %%
y1=len(euro12['Team'])

# %%
y1
# Out:
# 16

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
y2=len(euro12.columns)

# %%
y2
# Out:
# 35

# %% [markdown]
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline=euro12[['Team','Yellow Cards','Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(by=['Red Cards','Yellow Cards',],ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# Step 9. Calculate the mean Yellow Cards given per Team

# %%
discipline.groupby('Team')['Yellow Cards'].agg(['mean'])
# Out:
#                      mean
# Team
# Croatia                 9
# Czech Republic          7
# Denmark                 4
# England                 5
# France                  6
# Germany                 4
# Greece                  9
# Italy                  16
# Netherlands             5
# Poland                  7
# Portugal               12
# Republic of Ireland     6
# Russia                  6
# Spain                  11
# Sweden                  7
# Ukraine                 5

# %% [markdown]
# Step 10. Filter teams that scored more than 6 goals

# %%
euro12[euro12["Goals"].apply(lambda x: x>6)]["Team"]
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# Step 11. Select the teams that start with G

# %%
euro12[euro12["Team"].str.startswith('G')]["Team"]
# Out:
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %% [markdown]
# Step 12. Select the first 7 columns

# %%
euro12.iloc[:,:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 13. Select all columns except the last 3

# %%
euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[euro12["Team"].isin(['England', 'Italy', 'Russia']),['Shooting Accuracy']]
# Out:
#    Shooting Accuracy
# 3              50.0%
# 7              43.0%
# 12             22.5%

# %% [markdown]
# Question 3
# Housing
# Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Step 2. Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000

# %%
s1=pd.Series(np.random.randint(1,4,size=100))
s2=pd.Series(np.random.randint(1,3,size=100))
s3=pd.Series(np.random.randint(10000,30000,size=100))

# %% [markdown]
# Step 3. Create a DataFrame by joinning the Series by column

# %%
s=pd.concat([s1,s2,s3],axis=1)

# %% [markdown]
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df=pd.DataFrame(s)
df.columns=['bedrs','bathrs','price_sqr_meter']

# %% [markdown]
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn=pd.concat([s1,s2,s3])

# %% [markdown]
# Step 6. Ops it seems it is going only until index 99. Is it true?
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn.reset_index()
# Out:
#      index      0
# 0        0      2
# 1        1      2
# 2        2      3
# 3        3      1
# 4        4      3
# ..     ...    ...
# 295     95  11992
# 296     96  11088
# 297     97  12195
# 298     98  28680
# 299     99  24087
#
# [300 rows x 2 columns]

# %% [markdown]
# Question 4
# Wind Statistics
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
# You should be able to perform all of these operations without using a for loop or
# other looping construct.
# The data in 'wind.data' has the following format:
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL
# MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
# The first three columns are year, month, and day. The remaining 12 columns are
# average windspeeds in knots at 12 locations in Ireland on that day.

# %% [markdown]
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from the attached file wind.txt
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper
# datetime index

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('C:\\Users\\Nandu R R\\Documents\\BDAT\\Data Programming\\wind.csv')

# %%
data.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
data["DT"] = pd.to_datetime(data[["Yr","Mo","Dy"]].astype(str).agg('-'.join, axis=1))
data=data.drop(columns=["Yr","Mo","Dy"])

# %% [markdown]
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
data["DT"] = np.where(pd.DatetimeIndex(data["DT"]).year < 2000,data.DT,data.DT - pd.offsets.DateOffset(years=100))
data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL         DT
# 0     18.50  15.04 1961-01-01
# ...

# %% [markdown]
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.set_index('DT',inplace=True)

# %% [markdown]
# Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.

# %%
n1=data.isnull().sum()

# %%
n1=n1.sum()
n1
# Out:
# 31

# %% [markdown]
# Step 7. Compute how many non-missing values there are in total.

# %%
n2=data.notnull().sum().sum()

# %%
n2
# Out:
# 78857

# %% [markdown]
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.A single number for the entire dataset.

# %%
x=data.agg(['mean'])

# %%
x.agg(['mean'],axis=1)
# Out:
#            mean
# mean  10.227982

# %%
Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds 
and standard deviations of the windspeeds at each location over all the days.
A different set of numbers for each location.

# %%
loc_stats=pd.DataFrame(data=[data.min(),data.max(),data.mean(),data.std()],index=['mean','max','min','sd'])

# %%
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# mean   0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# min   12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# sd     5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# mean   0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# min    9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# sd     4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %% [markdown]
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations
# of the windspeeds across all the locations at each day.A different set of numbers for each day

# %%
d=data.transpose()

# %%
day_stats=pd.DataFrame([d.min(),d.max(),d.mean(),d.std()]).transpose()
day_stats.columns=['mean','max','min','std']
day_stats
# Out:
#             mean    max        min       std
# DT
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %%
Step 11. Find the average windspeed in January for each location.
Treat January 1961 and January 1962 both as January.

# %%
d1=data.reset_index()
d1["DT"]=d1["DT"].apply(pd.to_datetime)
d1.set_index("DT",inplace=True)

# %%
j=d1[d1.index.month == 1].agg(['mean'])
j
# Out:
#             RPT       VAL        ROS       KIL        SHA       BIR  \
# mean  14.847325  12.91456  13.299624  7.199498  11.667734  8.054839
#
#             DUB       CLA       MUL        CLO       BEL        MAL
# mean  11.819355  9.512047  9.543208  10.053566  14.55052  18.028763

# %% [markdown]
# Step 12. Downsample the record to a yearly frequency for each location.

# %%
d1.resample('Y').agg(['mean'])
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
#                  mean       mean       mean      mean       mean      mean
# DT
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# ...

# %%
d1.resample('M').agg(['mean'])
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
#                  mean       mean       mean      mean       mean       mean
# DT
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# ...

# %%
d1.resample('W').agg(['mean'])
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
#                  mean       mean       mean       mean       mean       mean
# DT
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# ...

# %% [markdown]
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations
# for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
f = d1[d1.index.year == 1961].resample('W').mean().apply(lambda x: x.describe())
f
# Out:
#              RPT        VAL        ROS        KIL        SHA        BIR  \
# count  53.000000  53.000000  53.000000  53.000000  52.000000  53.000000
# mean   12.341033  10.419380  11.381716   6.990952  10.876502   7.764340
# std     3.390879   2.874840   2.830804   2.072540   2.677186   2.426115
# min     4.202857   4.255714   6.738571   3.300000   6.112857   2.715714
# 25%    10.236667   8.445714   9.104286   5.478571   8.966071   6.017143
# 50%    11.715714   9.734286  10.875714   6.578571  10.357143   7.492857
# 75%    15.130000  12.951429  13.170000   8.370000  13.277857   9.238571
# max    19.880000  16.417143  18.225714  12.720000  17.432857  14.828571
#
#              DUB        CLA        MUL        CLO        BEL        MAL
# count  53.000000  53.000000  53.000000  53.000000  53.000000  53.000000
# mean    9.805135   8.869915   8.694681   9.872951  13.583612  13.707255
# std     2.837580   2.440596   2.404598   2.588429   3.646558   3.551007
# ...

# %% [markdown]
# Question 5
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.

# %%
import numpy as np
import pandas as pd

# %%
chipo=pd.read_csv('C:\\Users\\Nandu R R\\Documents\\BDAT\\Data Programming\\chipo.csv')

# %% [markdown]
# Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %% [markdown]
# Step 5. What is the number of observations in the dataset?

# %%
chipo.shape[0]
# Out:
# 4622

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# Step 7. Print the name of all the columns.

# %%
print(chipo.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# Step 9. Which was the most-ordered item?

# %%
chipo.item_name.value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %% [markdown]
# Step 10. For the most-ordered item, how many items were ordered?

# %%
chipo.item_name.value_counts().max()
# Out:
# 726

# %% [markdown]
# Step 11. What was the most ordered item in the choice_description column?

# %%
chipo.choice_description.value_counts().max()
# Out:
# 134

# %% [markdown]
# Step 12. How many items were orderd in total?

# %%
len(chipo.item_name.unique())
# Out:
# 50

# %% [markdown]
# Step 13. • Turn the item price into a float

# %%
chipo["item_price"].astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# Check the item price type

# %%
chipo["item_price"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Create a lambda function and change the type of item price

# %%
df = pd.DataFrame(map(lambda x: pd.to_numeric(chipo["item_price"], errors='coerce'), x) for x in chipo.columns)

# %% [markdown]
# Step 14. How much was the revenue

# %%
r=(chipo["item_price"]*chipo["quantity"]).sum()
r
# Out:
# 39237.02

# %% [markdown]
# Step 15. How many orders were made in the period?

# %%
o=len(chipo["order_id"].unique())
o
# Out:
# 1834

# %% [markdown]
# Step 16. What is the average revenue amount per order?

# %%
r.sum()/o
# Out:
# 21.39423118865867

# %% [markdown]
# Step 17. How many different items are sold?

# %%
len(chipo["item_name"].unique())
# Out:
# 50

# %% [markdown]
# Question 6

# %% [markdown]
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dm=pd.read_csv('C:\\Users\\Nandu R R\\Documents\\BDAT\\Data Programming\\us-marriages-divorces-1867-2014.csv')

# %%
dm.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
dm.plot(kind='line',x='Year',y=['Marriages_per_1000','Divorces_per_1000'],xlabel= 'Year',ylabel='Marriages & Divorces')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Marriages & Divorces'>

# %% [markdown]
# Question 7
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
actor=pd.read_csv('C:\\Users\\Nandu R R\\Documents\\BDAT\\Data Programming\\actor_kill_counts.csv')

# %%
dm[(dm['Year'].isin([1900,1950,2000]))].plot.bar(x='Year',y=['Marriages_per_1000','Divorces_per_1000'],xlabel='Year',ylabel='Marriages & Divorcers per capita')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Marriages & Divorcers per capita'>

# %% [markdown]
# Question 8
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
x=actor.set_index('Actor').sort_values('Count').plot(kind='barh',)
x.set_xlabel("Kill count")
# Out:
# Text(0.5, 0, 'Kill count')

# %% [markdown]
# Question 9
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.

# %%
emp=pd.read_csv('C:\\Users\\Nandu R R\\Documents\\BDAT\\Data Programming\\roman-emperor-reigns.csv')

# %%
emp[(emp['Cause_of_Death']=='Assassinated')].set_index('Emperor').plot(kind='pie',x='Emperor',y='Length_of_Reign',figsize=(8,8),autopct='%1.1f%%').legend(bbox_to_anchor=(1.5,1))

# %% [markdown]
# Question 10
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.

# %%
comp=pd.read_csv('C:\\Users\\Nandu R R\\Documents\\BDAT\\Data Programming\\arcade-revenue-vs-cs-doctorates.csv')

# %%
sns.lmplot('Total Arcade Revenue (billions)', 'Computer Science Doctorates Awarded (US)', data=comp, hue='Year', fit_reg=False)
# Out:
# C:\Users\Nandu R R\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
